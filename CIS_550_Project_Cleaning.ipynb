# %%
import json
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
rec_df = pd.read_csv("recipes.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-416578bb4cb3> in <cell line: 1>()
# ----> 1 rec_df = pd.read_csv("recipes.csv")
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     676     kwds.update(kwds_defaults)
#     677
# --> 678     return _read(filepath_or_buffer, kwds)
#     679
#     680
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     573
#     574     # Create the parser.
# --> 575     parser = TextFileReader(filepath_or_buffer, **kwds)
#     576
#     577     if chunksize or iterator:
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     930
#     931         self.handles: IOHandles | None = None
# --> 932         self._engine = self._make_engine(f, self.engine)
#     933
#     934     def close(self):
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1214             # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1215             # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1216             self.handles = get_handle(  # type: ignore[call-overload]
#    1217                 f,
#    1218                 mode,
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784         if ioargs.encoding and "b" not in ioargs.mode:
#     785             # Encoding
# --> 786             handle = open(
#     787                 handle,
#     788                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'recipes.csv'

# %%
rev_df = pd.read_csv("reviews.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-88c6d4151175> in <cell line: 1>()
# ----> 1 rev_df = pd.read_csv("reviews.csv")
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     676     kwds.update(kwds_defaults)
#     677
# --> 678     return _read(filepath_or_buffer, kwds)
#     679
#     680
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     573
#     574     # Create the parser.
# --> 575     parser = TextFileReader(filepath_or_buffer, **kwds)
#     576
#     577     if chunksize or iterator:
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     930
#     931         self.handles: IOHandles | None = None
# --> 932         self._engine = self._make_engine(f, self.engine)
#     933
#     934     def close(self):
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1214             # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1215             # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1216             self.handles = get_handle(  # type: ignore[call-overload]
#    1217                 f,
#    1218                 mode,
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784         if ioargs.encoding and "b" not in ioargs.mode:
#     785             # Encoding
# --> 786             handle = open(
#     787                 handle,
#     788                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'reviews.csv'

# %%
rec_df
# Out:
#         RecipeId                                              Name  \
# 0             38                 Low-Fat Berry Blue Frozen Dessert
# 1             39                                           Biryani
# 2             40                                     Best Lemonade
# 3             41                    Carina's Tofu-Vegetable Kebabs
# 4             42                                      Cabbage Soup
# ...          ...                                               ...
# 522512    541379                    Meg's Fresh Ginger Gingerbread
# 522513    541380  Roast Prime Rib au Poivre with Mixed Peppercorns
# 522514    541381                             Kirshwasser Ice Cream
# 522515    541382          Quick & Easy Asian Cucumber Salmon Rolls
# 522516    541383                           Spicy Baked Scotch Eggs
#
#           AuthorId      AuthorName CookTime PrepTime TotalTime  \
# 0             1533          Dancer    PT24H    PT45M  PT24H45M
# 1             1567        elly9812    PT25M     PT4H   PT4H25M
# 2             1566  Stephen Little     PT5M    PT30M     PT35M
# 3             1586         Cyclopz    PT20M    PT24H  PT24H20M
# 4             1538       Duckie067    PT30M    PT20M     PT50M
# ...            ...             ...      ...      ...       ...
# 522512  2002090414           rdsxc    PT35M     PT1H   PT1H35M
# 522513      211566    Denver cooks     PT3H    PT30M   PT3H30M
# 522514  2001131545     Jonathan F.     PT3H     PT1H      PT4H
# 522515  2001004241       CLUBFOODY      NaN    PT15M     PT15M
# 522516      188099    Chef LauraMD    PT25M    PT15M     PT40M
#
#                DatePublished  \
# 0       1999-08-09T21:46:00Z
# 1       1999-08-29T13:12:00Z
# 2       1999-09-05T19:52:00Z
# 3       1999-09-03T14:54:00Z
# 4       1999-09-19T06:19:00Z
# ...                      ...
# 522512  2020-12-22T15:27:00Z
# 522513  2020-12-22T15:32:00Z
# 522514  2020-12-22T15:33:00Z
# 522515  2020-12-22T22:11:00Z
# 522516  2020-12-22T22:12:00Z
#
#                                               Description  \
# 0       Make and share this Low-Fat Berry Blue Frozen ...
# 1       Make and share this Biryani recipe from Food.com.
# 2       This is from one of my  first Good House Keepi...
# 3       This dish is best prepared a day in advance to...
# 4       Make and share this Cabbage Soup recipe from F...
# ...                                                   ...
# 522512  Make and share this Meg's Fresh Ginger Gingerb...
# 522513  White, black, green, and pink peppercorns add ...
# 522514  Make and share this Kirshwasser Ice Cream reci...
# 522515  Extremely quick and easy to make, these are gr...
# 522516  Great way to have hard boiled eggs and crispy,...
#
#                                                    Images  ...  \
# 0       c("https://img.sndimg.com/food/image/upload/w_...  ...
# 1       c("https://img.sndimg.com/food/image/upload/w_...  ...
# 2       c("https://img.sndimg.com/food/image/upload/w_...  ...
# 3       c("https://img.sndimg.com/food/image/upload/w_...  ...
# 4       "https://img.sndimg.com/food/image/upload/w_55...  ...
# ...                                                   ...  ...
# 522512                                       character(0)  ...
# 522513  "https://img.sndimg.com/food/image/upload/w_55...  ...
# 522514                                       character(0)  ...
# 522515  "https://img.sndimg.com/food/image/upload/w_55...  ...
# 522516                                       character(0)  ...
#
#        SaturatedFatContent CholesterolContent SodiumContent  \
# 0                      1.3                8.0          29.8
# 1                     16.6              372.8         368.4
# 2                      0.0                0.0           1.8
# 3                      3.8                0.0        1558.6
# 4                      0.1                0.0         959.3
# ...                    ...                ...           ...
# 522512                 7.6               54.4         278.2
# 522513                71.4              433.8         766.3
# 522514                72.6              470.9         192.5
# 522515                 0.1                2.9         100.5
# 522516                22.2             1769.7        1318.6
#
#        CarbohydrateContent  FiberContent  SugarContent  ProteinContent  \
# 0                     37.1           3.6          30.2             3.2
# 1                     84.4           9.0          20.4            63.4
# 2                     81.5           0.4          77.2             0.3
# 3                     64.2          17.3          32.1            29.3
# 4                     25.1           4.8          17.7             4.3
# ...                    ...           ...           ...             ...
# 522512                48.5           0.8          22.8             3.9
# 522513                 3.2           0.7           0.1           117.0
# 522514                33.9           0.0          17.3            12.8
# 522515                 0.3           0.0           0.1             2.4
# 522516                29.7           1.3           6.7            76.4
#
#         RecipeServings     RecipeYield  \
# 0                  4.0             NaN
# 1                  6.0             NaN
# 2                  4.0             NaN
# 3                  2.0        4 kebabs
# 4                  4.0             NaN
# ...                ...             ...
# 522512             8.0  1 8x8 cake pan
# 522513             8.0         1 Roast
# 522514             6.0             NaN
# 522515             NaN        20 rolls
# 522516             NaN             NaN
#
#                                        RecipeInstructions
# 0       c("Toss 2 cups berries with sugar.", "Let stan...
# 1       c("Soak saffron in warm milk for 5 minutes and...
# 2       c("Into a 1 quart Jar with tight fitting lid, ...
# 3       c("Drain the tofu, carefully squeezing out exc...
# 4       c("Mix everything together and bring to a boil...
# ...                                                   ...
# 522512  c("Preheat oven to 350&deg;F Grease an 8x8 cak...
# 522513  c("Position rack in center of oven and preheat...
# 522514  c("heat half and half and heavy cream to a sim...
# 522515  c("In a small bowl, combine mayo and wasabi pa...
# 522516  c("Mix sausage, panko, egg yolk and Wocestersh...
#
# [522517 rows x 28 columns]

# %%
rec_df = rec_df.dropna()
rec_df
# Out:
#         RecipeId                                  Name  AuthorId  \
# 3             41        Carina's Tofu-Vegetable Kebabs      1586
# 5             43                  Best Blackbottom Pie     34879
# 16            54                           Carrot Cake      1535
# 26            64                     Almond Pound Cake    125579
# 54            94                 Blueberry Buttertarts      1556
# ...          ...                                   ...       ...
# 520596    539304  Pork Tenderloin With Bacon-Onion Jam    400708
# 520760    539476   Thai Basil Chicken (Gai Pad Krapow)   1248549
# 521132    539867         Green Enchiladas Chicken Soup     65308
# 521418    540238                Keto King's Best Bread   1249567
# 522039    540899           Butter Pecan Banana Muffins   1827868
#
#                   AuthorName CookTime PrepTime TotalTime  \
# 3                    Cyclopz    PT20M    PT24H  PT24H20M
# 5       Barefoot Beachcomber     PT2H    PT20M   PT2H20M
# 16        Marg CaymanDesigns    PT50M    PT45M   PT1H35M
# 26          GrandmaIsCooking     PT1H    PT15M   PT1H15M
# 54           Strawberry Girl    PT25M    PT15M     PT40M
# ...                      ...      ...      ...       ...
# 520596            Bonnie G 2     PT1H    PT20M   PT1H20M
# 520760       StrawberryAnnie     PT7M     PT3M     PT10M
# 521132            agileangus     PT8H    PT10M   PT8H10M
# 521418   Retired Greyhound M    PT25M     PT3H   PT3H25M
# 522039                 jarp4    PT18M    PT10M     PT28M
#
#                DatePublished  \
# 3       1999-09-03T14:54:00Z
# 5       1999-08-21T10:35:00Z
# 16      1999-09-13T15:20:00Z
# 26      1999-08-07T16:33:00Z
# 54      1999-09-12T05:46:00Z
# ...                      ...
# 520596  2019-09-23T13:04:00Z
# 520760  2019-11-07T14:45:00Z
# 521132  2020-02-20T20:11:00Z
# 521418  2020-05-01T21:39:00Z
# 522039  2020-09-01T20:59:00Z
#
#                                               Description  \
# 3       This dish is best prepared a day in advance to...
# 5       Make and share this Best Blackbottom Pie recip...
# 16      This is one of the few recipes my husband ever...
# 26      Make and share this Almond Pound Cake recipe f...
# 54      Make and share this Blueberry Buttertarts reci...
# ...                                                   ...
# 520596  Saw this on foodnetwork.com and knew I had to ...
# 520760  Make and share this Thai Basil Chicken (Gai Pa...
# 521132  Make and share this Green Enchiladas Chicken S...
# 521418  Make and share this Keto King's Best Bread rec...
# 522039  Make and share this Butter Pecan Banana Muffin...
#
#                                                    Images  ...  \
# 3       c("https://img.sndimg.com/food/image/upload/w_...  ...
# 5                                            character(0)  ...
# 16      c("https://img.sndimg.com/food/image/upload/w_...  ...
# 26                                           character(0)  ...
# 54                                           character(0)  ...
# ...                                                   ...  ...
# 520596  c("https://img.sndimg.com/food/image/upload/w_...  ...
# 520760                                       character(0)  ...
# 521132  "https://img.sndimg.com/food/image/upload/w_55...  ...
# 521418  c("https://img.sndimg.com/food/image/upload/w_...  ...
# 522039                                       character(0)  ...
#
#        SaturatedFatContent CholesterolContent SodiumContent  \
# 3                      3.8                0.0        1558.6
# 5                     10.9               94.3         267.6
# 16                     4.9               69.8         534.8
# 26                     9.0              118.9         159.4
# 54                     4.7               17.6         125.7
# ...                    ...                ...           ...
# 520596                10.9              120.6         836.2
# 520760                 4.0               97.5         935.6
# 521132                15.0              190.3        1852.2
# 521418                 1.3               27.1         169.1
# 522039                 1.7               17.2         253.0
#
#        CarbohydrateContent  FiberContent  SugarContent  ProteinContent  \
# 3                     64.2          17.3          32.1            29.3
# 5                     58.0           1.8          42.5             7.0
# 16                    67.0           1.6          47.9             5.0
# 26                    56.0           1.3          29.0             6.9
# 54                    40.2           1.2          11.5             4.2
# ...                    ...           ...           ...             ...
# 520596                22.3           0.8          19.4            33.2
# 520760                 9.8           0.7           4.3            22.6
# 521132                12.8           0.0          10.8            54.2
# 521418                 2.1           1.5           0.5             2.0
# 522039                28.9           1.6          15.8             3.3
#
#         RecipeServings   RecipeYield  \
# 3                  2.0      4 kebabs
# 5                  8.0  1 9-inch pie
# 16                12.0       1 bundt
# 26                10.0        1 cake
# 54                12.0      12 tarts
# ...                ...           ...
# 520596             4.0  1 tenderloin
# 520760             4.0             4
# 521132             6.0       12 Cups
# 521418            16.0        1 Loaf
# 522039            12.0    12 Muffins
#
#                                        RecipeInstructions
# 3       c("Drain the tofu, carefully squeezing out exc...
# 5       c("Graham Cracker Crust: In small bowl, combin...
# 16      c("Beat together the eggs, oil, and white suga...
# 26      c("Preheat oven to 350 degrees Fahrenheit.", "...
# 54      c("Preheat oven to 375F.", "Leave shells in fo...
# ...                                                   ...
# 520596  c("For the bacon-onion jam: Heat the oil in a ...
# 520760  c("In a wok over high heat, add the oil, chili...
# 521132  c("In a 6 quart slow cooker add chicken breast...
# 521418  c("Combine yeast, honey and warm water.", "All...
# 522039  c("Heat oven to 375 degrees. Coat a standard 1...
#
# [28014 rows x 28 columns]

# %%
datetime = pd.to_datetime(rec_df['DatePublished'])
rec_df['DatePublished'] = datetime.dt.date
# Out:
# <ipython-input-7-31350a585431>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rec_df['DatePublished'] = datetime.dt.date

# %%
rec_df['Description'] = rec_df['Description'].apply(str.lower)
# Out:
# <ipython-input-8-008bdf561ea8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rec_df['Description'] = rec_df['Description'].apply(str.lower)

# %%
rec_df['RecipeCategory'] = rec_df['RecipeCategory'].apply(str.lower)
# Out:
# <ipython-input-10-6e1e759b4580>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rec_df['RecipeCategory'] = rec_df['RecipeCategory'].apply(str.lower)

# %%
rec_df['Keywords'] = rec_df['Keywords'].apply(str.lower)
# Out:
# <ipython-input-11-232f20a68d2b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rec_df['Keywords'] = rec_df['Keywords'].apply(str.lower)

# %%
rec_df['RecipeIngredientParts'] = rec_df['RecipeIngredientParts'].apply(str.lower)
# Out:
# <ipython-input-12-98c091e4d890>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rec_df['RecipeIngredientParts'] = rec_df['RecipeIngredientParts'].apply(str.lower)

# %%
rec_df['RecipeInstructions'] = rec_df['RecipeInstructions'].apply(str.lower)
# Out:
# <ipython-input-13-0be5405327f7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rec_df['RecipeInstructions'] = rec_df['RecipeInstructions'].apply(str.lower)

# %%
rec_df.head(5)
# Out:
#     RecipeId                            Name  AuthorId            AuthorName  \
# 3         41  Carina's Tofu-Vegetable Kebabs      1586               Cyclopz
# 5         43            Best Blackbottom Pie     34879  Barefoot Beachcomber
# 16        54                     Carrot Cake      1535    Marg CaymanDesigns
# 26        64               Almond Pound Cake    125579      GrandmaIsCooking
# 54        94           Blueberry Buttertarts      1556       Strawberry Girl
#
#    CookTime PrepTime TotalTime DatePublished  \
# 3     PT20M    PT24H  PT24H20M    1999-09-03
# 5      PT2H    PT20M   PT2H20M    1999-08-21
# 16    PT50M    PT45M   PT1H35M    1999-09-13
# 26     PT1H    PT15M   PT1H15M    1999-08-07
# 54    PT25M    PT15M     PT40M    1999-09-12
#
#                                           Description  \
# 3   this dish is best prepared a day in advance to...
# 5   make and share this best blackbottom pie recip...
# 16  this is one of the few recipes my husband ever...
# 26  make and share this almond pound cake recipe f...
# 54  make and share this blueberry buttertarts reci...
#
#                                                Images  ...  \
# 3   c("https://img.sndimg.com/food/image/upload/w_...  ...
# 5                                        character(0)  ...
# 16  c("https://img.sndimg.com/food/image/upload/w_...  ...
# 26                                       character(0)  ...
# 54                                       character(0)  ...
#
#    SaturatedFatContent CholesterolContent SodiumContent CarbohydrateContent  \
# 3                  3.8                0.0        1558.6                64.2
# 5                 10.9               94.3         267.6                58.0
# 16                 4.9               69.8         534.8                67.0
# 26                 9.0              118.9         159.4                56.0
# 54                 4.7               17.6         125.7                40.2
#
#     FiberContent  SugarContent  ProteinContent  RecipeServings   RecipeYield  \
# 3           17.3          32.1            29.3             2.0      4 kebabs
# 5            1.8          42.5             7.0             8.0  1 9-inch pie
# 16           1.6          47.9             5.0            12.0       1 bundt
# 26           1.3          29.0             6.9            10.0        1 cake
# 54           1.2          11.5             4.2            12.0      12 tarts
#
#                                    RecipeInstructions
# 3   c("drain the tofu, carefully squeezing out exc...
# 5   c("graham cracker crust: in small bowl, combin...
# 16  c("beat together the eggs, oil, and white suga...
# 26  c("preheat oven to 350 degrees fahrenheit.", "...
# 54  c("preheat oven to 375f.", "leave shells in fo...
#
# [5 rows x 28 columns]

# %%
rec_df.dtypes
# Out:
# RecipeId                        int64
# Name                           object
# AuthorId                        int64
# AuthorName                     object
# CookTime                       object
# PrepTime                       object
# TotalTime                      object
# DatePublished                  object
# Description                    object
# Images                         object
# RecipeCategory                 object
# Keywords                       object
# RecipeIngredientQuantities     object
# RecipeIngredientParts          object
# AggregatedRating              float64
# ReviewCount                   float64
# Calories                      float64
# FatContent                    float64
# SaturatedFatContent           float64
# CholesterolContent            float64
# SodiumContent                 float64
# CarbohydrateContent           float64
# FiberContent                  float64
# SugarContent                  float64
# ProteinContent                float64
# RecipeServings                float64
# RecipeYield                    object
# RecipeInstructions             object
# dtype: object

# %%
def get_minutes(x):
  num_hours = 0
  num_minutes = 0
  if 'H' in x and 'M' in x:
    loc_h = x.find('H')
    num_hours = int(x[2:loc_h])
    num_minutes = int(x[loc_h + 1: -1])
  elif 'H' in x:
    num_hours = int(x[2:-1])
  else:
    num_minutes = int(x[2:-1])
  return (60 * num_hours) + num_minutes
  #used this to get cook, prep, and total time in minutes

# %%
rec_df['CookTime'] = rec_df['CookTime'].apply(lambda x: get_minutes(str(x)))
rec_df['CookTime'].head(5)
# Out:
# <ipython-input-17-1c8061964ed3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rec_df['CookTime'] = rec_df['CookTime'].apply(lambda x: get_minutes(str(x)))
# 3      20
# 5     120
# 16     50
# 26     60
# 54     25
# Name: CookTime, dtype: int64

# %%
rec_df['PrepTime'] = rec_df['PrepTime'].apply(lambda x: get_minutes(str(x)))
rec_df['PrepTime'].head(5)
# Out:
# <ipython-input-18-af07d900e2ea>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rec_df['PrepTime'] = rec_df['PrepTime'].apply(lambda x: get_minutes(str(x)))
# 3     1440
# 5       20
# 16      45
# 26      15
# 54      15
# Name: PrepTime, dtype: int64

# %%
rec_df['TotalTime'] = rec_df['TotalTime'].apply(lambda x: get_minutes(str(x)))
rec_df['TotalTime'].head(5)
# Out:
# <ipython-input-19-767af6b28e94>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rec_df['TotalTime'] = rec_df['TotalTime'].apply(lambda x: get_minutes(str(x)))
# 3     1460
# 5      140
# 16      95
# 26      75
# 54      40
# Name: TotalTime, dtype: int64

# %%
rec_df['IngredientsList'] = rec_df['RecipeIngredientParts'].apply(lambda x: x.replace('"', '').replace('c(', '').replace(')', '').split(', '))
# Out:
# <ipython-input-20-2f7a62bd193f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rec_df['IngredientsList'] = rec_df['RecipeIngredientParts'].apply(lambda x: x.replace('"', '').replace('c(', '').replace(')', '').split(', '))

# %%
rec_df['IngredientsCount'] = rec_df['IngredientsList'].apply(lambda x: len(x))
# Out:
# <ipython-input-21-7e2b21a438fc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rec_df['IngredientsCount'] = rec_df['IngredientsList'].apply(lambda x: len(x))

# %%
rec_df['NummberOfLikes'] = 0

# %%
rec_cleaned_df = rec_df.to_csv('rec_cleaned_df.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ce23688b783a> in <cell line: 1>()
# ----> 1 rec_cleaned_df = rec_df.to_csv('rec_cleaned_df.csv')
#
# NameError: name 'rec_df' is not defined

# %%
rev_df
# Out:
#          ReviewId  RecipeId    AuthorId        AuthorName  Rating  \
# 0               2       992        2008         gayg msft       5
# 1               7      4384        1634     Bill Hilbrich       4
# 2               9      4523        2046  Gay Gilmore ckpt       2
# 3              13      7435        1773     Malarkey Test       5
# 4              14        44        2085        Tony Small       5
# ...           ...       ...         ...               ...     ...
# 1401977   2090339    139499  2002080368       terrylbiggs       2
# 1401978   2090340    148484    41805321        rogerberry       5
# 1401979   2090341    264191  2002901848    Reiketsukan 6.       5
# 1401980   2090345    411791  2002901938            Sue M.       5
# 1401981   2090347    352686  2002812127        dede25cory       5
#
#                                                     Review  \
# 0             better than any you can get at a restaurant!
# 1        I cut back on the mayo, and made up the differ...
# 2        i think i did something wrong because i could ...
# 3        easily the best i have ever had.  juicy flavor...
# 4                                       An excellent dish.
# ...                                                    ...
# 1401977  I was disappointed. I couldn't wait to make th...
# 1401978  Nothing to drain. And I don’t heat up the liqu...
# 1401979  Good base recipe for someone to start with. I ...
# 1401980  Thank you so much for this amazing recipe! I l...
# 1401981  I can't say enough about this recipe.... the b...
#
#                 DateSubmitted          DateModified
# 0        2000-01-25T21:44:00Z  2000-01-25T21:44:00Z
# 1        2001-10-17T16:49:59Z  2001-10-17T16:49:59Z
# 2        2000-02-25T09:00:00Z  2000-02-25T09:00:00Z
# 3        2000-03-13T21:15:00Z  2000-03-13T21:15:00Z
# 4        2000-03-28T12:51:00Z  2000-03-28T12:51:00Z
# ...                       ...                   ...
# 1401977  2020-12-27T23:57:54Z  2020-12-27T23:57:54Z
# 1401978  2020-12-28T00:44:42Z  2020-12-28T00:44:42Z
# 1401979  2020-12-28T01:04:43Z  2020-12-28T01:04:43Z
# 1401980  2020-12-28T03:07:10Z  2020-12-28T03:07:10Z
# 1401981  2020-12-28T03:23:48Z  2020-12-28T03:23:48Z
#
# [1401982 rows x 8 columns]

# %%
rev_df = rev_df.dropna()
rev_df
# Out:
#          ReviewId  RecipeId    AuthorId        AuthorName  Rating  \
# 0               2       992        2008         gayg msft       5
# 1               7      4384        1634     Bill Hilbrich       4
# 2               9      4523        2046  Gay Gilmore ckpt       2
# 3              13      7435        1773     Malarkey Test       5
# 4              14        44        2085        Tony Small       5
# ...           ...       ...         ...               ...     ...
# 1401977   2090339    139499  2002080368       terrylbiggs       2
# 1401978   2090340    148484    41805321        rogerberry       5
# 1401979   2090341    264191  2002901848    Reiketsukan 6.       5
# 1401980   2090345    411791  2002901938            Sue M.       5
# 1401981   2090347    352686  2002812127        dede25cory       5
#
#                                                     Review  \
# 0             better than any you can get at a restaurant!
# 1        I cut back on the mayo, and made up the differ...
# 2        i think i did something wrong because i could ...
# 3        easily the best i have ever had.  juicy flavor...
# 4                                       An excellent dish.
# ...                                                    ...
# 1401977  I was disappointed. I couldn't wait to make th...
# 1401978  Nothing to drain. And I don’t heat up the liqu...
# 1401979  Good base recipe for someone to start with. I ...
# 1401980  Thank you so much for this amazing recipe! I l...
# 1401981  I can't say enough about this recipe.... the b...
#
#                 DateSubmitted          DateModified
# 0        2000-01-25T21:44:00Z  2000-01-25T21:44:00Z
# 1        2001-10-17T16:49:59Z  2001-10-17T16:49:59Z
# 2        2000-02-25T09:00:00Z  2000-02-25T09:00:00Z
# 3        2000-03-13T21:15:00Z  2000-03-13T21:15:00Z
# 4        2000-03-28T12:51:00Z  2000-03-28T12:51:00Z
# ...                       ...                   ...
# 1401977  2020-12-27T23:57:54Z  2020-12-27T23:57:54Z
# 1401978  2020-12-28T00:44:42Z  2020-12-28T00:44:42Z
# 1401979  2020-12-28T01:04:43Z  2020-12-28T01:04:43Z
# 1401980  2020-12-28T03:07:10Z  2020-12-28T03:07:10Z
# 1401981  2020-12-28T03:23:48Z  2020-12-28T03:23:48Z
#
# [1401768 rows x 8 columns]

# %%
datetime = pd.to_datetime(rev_df['DateSubmitted'])
rev_df['DateSubmitted'] = datetime.dt.date
# Out:
# <ipython-input-26-256518e6810c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rev_df['DateSubmitted'] = datetime.dt.date

# %%
datetime = pd.to_datetime(rev_df['DateModified'])
rev_df['DateModified'] = datetime.dt.date
# Out:
# <ipython-input-27-4cfacf997e76>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rev_df['DateModified'] = datetime.dt.date

# %%
rev_df.head(5)
# Out:
#    ReviewId  RecipeId  AuthorId        AuthorName  Rating  \
# 0         2       992      2008         gayg msft       5
# 1         7      4384      1634     Bill Hilbrich       4
# 2         9      4523      2046  Gay Gilmore ckpt       2
# 3        13      7435      1773     Malarkey Test       5
# 4        14        44      2085        Tony Small       5
#
#                                               Review DateSubmitted  \
# 0       better than any you can get at a restaurant!    2000-01-25
# 1  I cut back on the mayo, and made up the differ...    2001-10-17
# 2  i think i did something wrong because i could ...    2000-02-25
# 3  easily the best i have ever had.  juicy flavor...    2000-03-13
# 4                                 An excellent dish.    2000-03-28
#
#   DateModified
# 0   2000-01-25
# 1   2001-10-17
# 2   2000-02-25
# 3   2000-03-13
# 4   2000-03-28

# %%
rev_cleaned_df = rev_df.to_csv('rev_cleaned_df.csv')

# %%
rev_cleaned_df = pd.read_csv('rev_cleaned_df.csv')
rev_cleaned_df
# Out:
#          Unnamed: 0  ReviewId  RecipeId    AuthorId        AuthorName  Rating  \
# 0                 0         2       992        2008         gayg msft       5
# 1                 1         7      4384        1634     Bill Hilbrich       4
# 2                 2         9      4523        2046  Gay Gilmore ckpt       2
# 3                 3        13      7435        1773     Malarkey Test       5
# 4                 4        14        44        2085        Tony Small       5
# ...             ...       ...       ...         ...               ...     ...
# 1401763     1401977   2090339    139499  2002080368       terrylbiggs       2
# 1401764     1401978   2090340    148484    41805321        rogerberry       5
# 1401765     1401979   2090341    264191  2002901848    Reiketsukan 6.       5
# 1401766     1401980   2090345    411791  2002901938            Sue M.       5
# 1401767     1401981   2090347    352686  2002812127        dede25cory       5
#
#                                                     Review DateSubmitted  \
# 0             better than any you can get at a restaurant!    2000-01-25
# 1        I cut back on the mayo, and made up the differ...    2001-10-17
# 2        i think i did something wrong because i could ...    2000-02-25
# 3        easily the best i have ever had.  juicy flavor...    2000-03-13
# 4                                       An excellent dish.    2000-03-28
# ...                                                    ...           ...
# 1401763  I was disappointed. I couldn't wait to make th...    2020-12-27
# 1401764  Nothing to drain. And I don’t heat up the liqu...    2020-12-28
# 1401765  Good base recipe for someone to start with. I ...    2020-12-28
# 1401766  Thank you so much for this amazing recipe! I l...    2020-12-28
# 1401767  I can't say enough about this recipe.... the b...    2020-12-28
#
#         DateModified
# 0         2000-01-25
# 1         2001-10-17
# 2         2000-02-25
# 3         2000-03-13
# 4         2000-03-28
# ...              ...
# 1401763   2020-12-27
# 1401764   2020-12-28
# 1401765   2020-12-28
# 1401766   2020-12-28
# 1401767   2020-12-28
#
# [1401768 rows x 9 columns]

# %%
rev_cleaned_df.head(5)
# Out:
#    Unnamed: 0  ReviewId  RecipeId  AuthorId        AuthorName  Rating  \
# 0           0         2       992      2008         gayg msft       5
# 1           1         7      4384      1634     Bill Hilbrich       4
# 2           2         9      4523      2046  Gay Gilmore ckpt       2
# 3           3        13      7435      1773     Malarkey Test       5
# 4           4        14        44      2085        Tony Small       5
#
#                                               Review DateSubmitted  \
# 0       better than any you can get at a restaurant!    2000-01-25
# 1  I cut back on the mayo, and made up the differ...    2001-10-17
# 2  i think i did something wrong because i could ...    2000-02-25
# 3  easily the best i have ever had.  juicy flavor...    2000-03-13
# 4                                 An excellent dish.    2000-03-28
#
#   DateModified
# 0   2000-01-25
# 1   2001-10-17
# 2   2000-02-25
# 3   2000-03-13
# 4   2000-03-28

# %% [markdown]
# Used below for Milestone 1

# %%
cal_avg = rec_df['Calories'].mean()
cal_avg
# Out:
# 338.44805811380024

# %%
fat_avg = rec_df['FatContent'].mean()
fat_avg
# Out:
# 16.69129720853859

# %%
fat_sd = rec_df['FatContent'].std()
fat_sd
# Out:
# 41.03378221120556

# %%
revc_avg = rec_df['ReviewCount'].mean()
revc_avg
# Out:
# 4.9383165560077105

# %%
revc_sd = rec_df['ReviewCount'].std()
revc_sd
# Out:
# 24.3213629918943

# %%
rev_df = pd.read_csv("reviews.csv")

# %%
rev_df['Rating'].dtypes
# Out:
# dtype('int64')

# %%
rating_sd = rev_df['Rating'].std()
rating_sd
# Out:
# 1.2720116809642974

# %%
rating_avg = rev_df['Rating'].mean()
rating_avg
# Out:
# 4.407951029328479

# %%
revcount_sd = rev_df[['AuthorName']].groupby(['AuthorName']).count()
revcount_sd
# Out:
# Empty DataFrame
# Columns: []
# Index: [  B y r n s y  ,   sassanne,  .. Ameera .. ,  1 ARB,  Alison ,  Amber ,  ArabRider2,  Bahaa,  Butterbean,  C.7891,  CATE C.,  Carly ,  Coleman,  Cuisine ala Cathryn,  Dara ,  Dinah,  Donna ,  Dreaming ,  Glo ,  Gorgeous Goddyss ,  Its J ,  JLJ ,  KeLa ,  Kennethbyoung,  LadyZara ,  Lana ,  Little Homebaker ,  Little Miss ,  Pamela ,  Polly W,  Poppy ,  Ruby ,  Shugar,  Steve at KillerNOMS,  UPgirl,  Vivig,  X.4661,  alun fife,  chocoholic ,  dugarner,  eillehs03,  k.6642,  s.7785, - Andy, - Carla -, - DJ -, - G -, - Gail -, - H -, - Momma Loon, - Pinot Noir -, - TLC Creations, - Z4946, -- Jaime --, -------, --danton, -AdriBoo-, -Angie-, -Blondie-, -Blythe-, -BreanneMarie-, -Brenda-, -Derrick, -Eris-, -GEORGE-, -JL-6680, -JL5379, -JoeB, -KOL-, -Kraig-, -Linda-, -Lori-, -Mary-, -OceanGirl-, -Sabrina-, -Sam I Am-, -SharonKaysKitchen-, -Sheri-, -Sylvie-, -Tracy-, -Tulip-, -Val-, -Zombie-, -_-Rebecca-_-, -carmelina-, -d1473, -jasmine-, -sweet tart-, ...Myst..., ...Pammers..., ...Sabrina..., ...los212..., ..AW.., ..Barefoot and Happ, ..GlitterTequila.., ..Mamma Meshele.., ..cOoKiN MaMi.., ..therese.., ..tiffany.., .BarbaraAnn., ...]
#
# [241365 rows x 0 columns]

# %% [markdown]
# Found upper bounds for sliders

# %%
rec_cleaned_df = pd.read_csv("rec_cleaned_df.csv")

# %%
rec_cleaned_df.head(5)
# Out:
#    Unnamed: 0  RecipeId                            Name  AuthorId  \
# 0           3        41  Carina's Tofu-Vegetable Kebabs      1586
# 1           5        43            Best Blackbottom Pie     34879
# 2          16        54                     Carrot Cake      1535
# 3          26        64               Almond Pound Cake    125579
# 4          54        94           Blueberry Buttertarts      1556
#
#              AuthorName  CookTime  PrepTime  TotalTime DatePublished  \
# 0               Cyclopz        20      1440       1460        9/3/99
# 1  Barefoot Beachcomber       120        20        140       8/21/99
# 2    Marg CaymanDesigns        50        45         95       9/13/99
# 3      GrandmaIsCooking        60        15         75        8/7/99
# 4       Strawberry Girl        25        15         40       9/12/99
#
#                                          Description  ... SodiumContent  \
# 0  this dish is best prepared a day in advance to...  ...        1558.6
# 1  make and share this best blackbottom pie recip...  ...         267.6
# 2  this is one of the few recipes my husband ever...  ...         534.8
# 3  make and share this almond pound cake recipe f...  ...         159.4
# 4  make and share this blueberry buttertarts reci...  ...         125.7
#
#   CarbohydrateContent FiberContent SugarContent ProteinContent  \
# 0                64.2         17.3         32.1           29.3
# 1                58.0          1.8         42.5            7.0
# 2                67.0          1.6         47.9            5.0
# 3                56.0          1.3         29.0            6.9
# 4                40.2          1.2         11.5            4.2
#
#    RecipeServings   RecipeYield  \
# 0               2      4 kebabs
# 1               8  1 9-inch pie
# 2              12       1 bundt
# 3              10        1 cake
# 4              12      12 tarts
#
#                                   RecipeInstructions  \
# 0  c("drain the tofu, carefully squeezing out exc...
# 1  c("graham cracker crust: in small bowl, combin...
# 2  c("beat together the eggs, oil, and white suga...
# 3  c("preheat oven to 350 degrees fahrenheit.", "...
# 4  c("preheat oven to 375f.", "leave shells in fo...
#
#                                      IngredientsList  IngredientsCount
# 0  ['extra firm tofu', 'eggplant', 'zucchini', 'm...                14
# 1  ['graham cracker crumbs', 'sugar', 'butter', '...                13
# 2  ['carrots', 'eggs', 'white sugar', 'all-purpos...                14
# 3  ['butter', 'almond paste', 'sugar', 'eggs', 'f...                 8
# 4  ['egg', 'corn syrup', 'lemon juice', 'vanilla'...                 7
#
# [5 rows x 31 columns]

# %% [markdown]
# Used below for maximum numbers on search page

# %%
rec_cleaned_df['CookTime'].max()
# Out:
# 11358720

# %%
rec_cleaned_df['PrepTime'].max()
# Out:
# 525600

# %%
rec_cleaned_df['TotalTime'].max()
# Out:
# 11394720

# %%
rec_cleaned_df['SaturatedFatContent'].max()
# Out:
# 841.9

# %%
rec_cleaned_df['CholesterolContent'].max()
# Out:
# 9167.2

# %%
rec_cleaned_df['SodiumContent'].max()
# Out:
# 704129.6

# %%
rec_cleaned_df['CarbohydrateContent'].max()
# Out:
# 4320.9

# %%
rec_cleaned_df['ProteinContent'].max()
# Out:
# 1802.9

# %%
rec_cleaned_df['FiberContent'].max()
# Out:
# 835.7

# %%
rec_cleaned_df['SugarContent'].max()
# Out:
# 3623.9

# %%
rec_cleaned_df['RecipeYield'].max()
# Out:
# '96-100 cookies'

# %%
rec_cleaned_df['RecipeServings'].max()
# Out:
# 32767

# %%
rec_cleaned_df['IngredientsCount'].max()
# Out:
# 39

# %% [markdown]
# Used below for summary statistics in final report.

# %%
rec_cleaned_df['IngredientsCount'].mean()
# Out:
# 8.123085710205975

# %%
rec_cleaned_df['PrepTime'].mean()
# Out:
# 58.5838717738193

# %%
rec_cleaned_df['RecipeServings'].mean()
# Out:
# 13.390461571413272
